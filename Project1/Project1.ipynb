# %% [markdown]
# ---
# title: Project 1
# math:
#     '\abs': '\left\lvert #1 \right\rvert'
#     '\norm': '\left\lvert #1 \right\rvert'
#     '\Set': '\left\{ #1 \right\}'
#     '\mc': '\mathcal{#1}'
#     '\M': '\boldsymbol{#1}'
#     '\R': '\mathsf{#1}'
#     '\RM': '\boldsymbol{\mathsf{#1}}'
#     '\op': '\operatorname{#1}'
#     '\E': '\op{E}'
#     '\d': '\mathrm{\mathstrut d}'
#     '\Gini': '\operatorname{Gini}'
#     '\Info': '\operatorname{Info}'
#     '\Gain': '\operatorname{Gain}'
#     '\GainRatio': '\operatorname{GainRatio}'
# ---

# %% [markdown]
# ::::{attention}
#
# - Access [\[Witten11\]](https://ebookcentral.proquest.com/lib/cityuhk/reader.action?docID=634862&ppg=602) for the exercises. Use Weka or other tools like `sklearn` or `python-weka-wrapper3` to complete them.
# - Provide your final answers in the designated solution cells. You may add extra cells to show your steps.
# - Submit the notebook via NbGrader before the deadline. You can submit multiple times to avoid the costly mistake of forgetting to submit or last-minute technical issues that prevent you from submitting.
# - This is an individual project. Take proper measures to avoid any suspicion of plagiarism.
#
# ::::

# %% [markdown]
# ::::{admonition} Rubrics
#
# - This project is worth 75 points, constituting 10% of your course grade.
# - There are 14 exercises, each of which is worth 5 points:
#   - 5 points for a correct answer and excellent understanding.
#   - 3 points for a partially correct answer and some understanding.
#   - 1 point for a reasonable attempt.
# - The remaining 5 points are allocated for *clarity of your answers*:
#     - Properly typset your answers: You can use the [MyST markdown](https://mystmd.org/guide) in the JupyterLab markdown cell.
#     - Proof-read your answers: You can [select your answers for Jupyternaut](https://jupyter-ai.readthedocs.io/en/latest/users/index.html#asking-about-something-in-your-notebook) to proof-read.
# ::::

# %% [markdown]
# ## Visualizing Decision Trees and Rule Sets

# %% [markdown]
# Complete the following exercises in **Section 17.3**.

# %% [markdown]
# ::::{exercise} Ex 17.3.8
# :label: ex:17.3.8
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{exercise} Ex 17.3.9
# :label: ex:17.3.9
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{exercise} Ex 17.3.10
# :label: ex:17.3.10
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{exercise} Ex 17.3.11
# :label: ex:17.3.11
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{exercise} Ex 17.3.12
# :label: ex:17.3.12
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Attribute Selection

# %% [markdown]
# Complete the following exercises in **Section 17.2** and one additional exercise.

# %% [markdown]
# ::::{exercise} Ex 17.2.4
# :label: ex:17.2.4
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{exercise} Ex 17.2.5
# :label: ex:17.2.5
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{exercise}
# :label: ex:challenge
# If your answer to Ex 17.2.5 is "no", give a better performance estimate and the best subset of features for *deployment*. Explain how you obtain the estimate and subset, i.e., how you subdivide the dataset for training, validation, and testing, and which accuracy values you use to select the features for deployment.
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Automatic Attribute Selection

# %% [markdown]
# Complete the following exercises in **Section 17.4**.

# %% [markdown]
# ::::{exercise} Ex 17.4.8
# :label: ex:17.4.8
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{exercise} Ex 17.4.9
# :label: ex:17.4.9
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{exercise} Ex 17.4.10
# :label: ex:17.4.10
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{exercise} Ex 17.4.11
# :label: ex:17.4.11
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{exercise} Ex 17.4.12
# :label: ex:17.4.12
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{exercise} Ex 17.4.13
# :label: ex:17.4.13
# ::::

# %% [markdown]
# YOUR ANSWER HERE
